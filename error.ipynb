# %%
"""
[Classification Metrics]
  0. BG         | P:0.9998 | R:0.9997 | F1:0.9997
  1. PG         | P:0.9996 | R:0.9993 | F1:0.9995
  2. FAT        | P:1.0000 | R:0.9999 | F1:0.9999
  3. TG         | P:0.9992 | R:0.9995 | F1:0.9993
  4. LN         | P:0.9998 | R:0.9999 | F1:0.9999
  5. MS         | P:0.9995 | R:0.9975 | F1:0.9985
  6. Blood      | P:0.9999 | R:1.0000 | F1:0.9999
  7. Tra        | P:0.9997 | R:0.9993 | F1:0.9995
  8. ES         | P:0.0000 | R:0.0000 | F1:0.0000

 FAILED: The number of FixedLocator locations (9), usually from a call to set_ticks, does not match the number of labels (8).
Traceback (most recent call last):
  File "/home/chenhaoran/LoLA_hsViT/ablation.py", line 219, in run_single
    results = trainer.train()
  File "/home/chenhaoran/LoLA_hsViT/pipeline/trainer.py", line 521, in train
    self._plot_per_class_metrics(final_target, final_pred)
  File "/home/chenhaoran/LoLA_hsViT/pipeline/trainer.py", line 898, in _plot_per_class_metrics
    ax.set_xticklabels(names, rotation=45, ha='right', fontsize=9)
  File "/home/chenhaoran/BASE/anaconda3/envs/LoLA/lib/python3.9/site-packages/matplotlib/axes/_base.py", line 74, in wrapper
    return get_method(self)(*args, **kwargs)
  File "/home/chenhaoran/BASE/anaconda3/envs/LoLA/lib/python3.9/site-packages/matplotlib/axis.py", line 2071, in set_ticklabels
    raise ValueError(
ValueError: The number of FixedLocator locations (9), usually from a call to set_ticks, does not match the number of labels (8).
"""

# %%
from config import load_config
config = load_config()

names = config.clsf.targets[1:config.clsf.num]
print(names)
# Out:
# ['PG', 'FAT', 'TG', 'LN', 'MS', 'Blood', 'Tra', 'ES']
# /home/chenhaoran/BASE/anaconda3/envs/LoLA/lib/python3.9/site-packages/munch/__init__.py:24: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
